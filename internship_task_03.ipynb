# %%
import pandas as pd
import sqlite3


df = pd.read_csv('/data.csv', encoding='latin1')


conn = sqlite3.connect(':memory:')
df.to_sql('ecommerce', conn, index=False, if_exists='replace')
cursor = conn.cursor()


print("SELECT * FROM ecommerce LIMIT 5:")
print(pd.read_sql("SELECT * FROM ecommerce LIMIT 5;", conn))


print("\nItems with UnitPrice > 10:")
print(pd.read_sql("SELECT * FROM ecommerce WHERE UnitPrice > 10 LIMIT 5;", conn))

print("\nTop 5 expensive items:")
print(pd.read_sql("SELECT Description, UnitPrice FROM ecommerce ORDER BY UnitPrice DESC LIMIT 5;", conn))

print("\nAverage UnitPrice by Country:")
print(pd.read_sql("SELECT Country, AVG(UnitPrice) as AvgPrice FROM ecommerce GROUP BY Country LIMIT 5;", conn))

query5 = """
SELECT a.InvoiceNo, a.Description, b.Quantity
FROM ecommerce a
INNER JOIN ecommerce b ON a.StockCode = b.StockCode
LIMIT 5;
"""
print("\nSelf JOIN example (StockCode):")
print(pd.read_sql(query5, conn))

query6 = """
SELECT Description, UnitPrice
FROM ecommerce
WHERE UnitPrice > (SELECT AVG(UnitPrice) FROM ecommerce)
LIMIT 5;
"""
print("\nItems priced above average:")
print(pd.read_sql(query6, conn))

cursor.execute("""
CREATE VIEW high_value_items AS
SELECT StockCode, Description, UnitPrice
FROM ecommerce
WHERE UnitPrice > 20;
""")
print("\nView created: high_value_items")

print("\nItems from view (UnitPrice > 20):")
print(pd.read_sql("SELECT * FROM high_value_items LIMIT 5;", conn))

cursor.execute("CREATE INDEX idx_stockcode ON ecommerce(StockCode);")
print("\nIndex created on StockCode")

conn.close()
# Out:
# SELECT * FROM ecommerce LIMIT 5:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
#
# Items with UnitPrice > 10:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370      POST                          POSTAGE         3
# 1    536374     21258       VICTORIAN SEWING BOX LARGE        32
# 2   C536379         D                         Discount        -1
# 3    536382     22839  3 TIER CAKE TIN GREEN AND CREAM         2
# 4    536382     22838    3 TIER CAKE TIN RED AND CREAM         2
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:45      18.00     12583.0          France
# 1  12/1/2010 9:09      10.95     15100.0  United Kingdom
# 2  12/1/2010 9:41      27.50     14527.0  United Kingdom
# 3  12/1/2010 9:45      14.95     16098.0  United Kingdom
# 4  12/1/2010 9:45      14.95     16098.0  United Kingdom
#
# Top 5 expensive items:
#   Description  UnitPrice
# 0      Manual   38970.00
# 1  AMAZON FEE   17836.46
# 2  AMAZON FEE   16888.02
# 3  AMAZON FEE   16453.71
# 4  AMAZON FEE   13541.33
#
# Average UnitPrice by Country:
#      Country  AvgPrice
# 0  Australia  3.220612
# 1    Austria  4.243192
# 2    Bahrain  4.556316
# 3    Belgium  3.644335
# 4     Brazil  4.456250
#
# Self JOIN example (StockCode):
#   InvoiceNo                         Description  Quantity
# 0    536365  WHITE HANGING HEART T-LIGHT HOLDER     -1930
# 1    536365  WHITE HANGING HEART T-LIGHT HOLDER      -500
# 2    536365  WHITE HANGING HEART T-LIGHT HOLDER      -256
# 3    536365  WHITE HANGING HEART T-LIGHT HOLDER       -24
# 4    536365  WHITE HANGING HEART T-LIGHT HOLDER       -18
#
# Items priced above average:
#                       Description  UnitPrice
# 0    SET 7 BABUSHKA NESTING BOXES       7.65
# 1   BOX OF VINTAGE JIGSAW BLOCKS        4.95
# 2  BOX OF VINTAGE ALPHABET BLOCKS       9.95
# 3        HOME BUILDING BLOCK WORD       5.95
# 4        LOVE BUILDING BLOCK WORD       5.95
#
# View created: high_value_items
#
# Items from view (UnitPrice > 20):
#   StockCode                         Description  UnitPrice
# 0         D                            Discount      27.50
# 1     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD     165.00
# 2     22803            IVORY EMBROIDERED QUILT       35.75
# 3     22803            IVORY EMBROIDERED QUILT       35.75
# 4        C2                            CARRIAGE      50.00
#
# Index created on StockCode
